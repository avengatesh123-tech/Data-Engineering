# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect()

orders = con.execute("""
SELECT *
FROM read_parquet('data/orders/*.parquet')
""").df()

orders.head()

# %%
orders.shape

# %%
orders.columns

# %%
SELECT COUNT(*) AS total_orders
FROM read_parquet('data/orders/*.parquet');
